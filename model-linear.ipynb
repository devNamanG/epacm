# %%
pip install pandas matplotlib scikit-learn seaborn xgboost
# Out:
# Requirement already satisfied: pandas in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: scikit-learn in /home/namanbgor/.local/lib/python3.12/site-packages (1.5.2)
# Requirement already satisfied: seaborn in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: xgboost in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.26.0 in /home/namanbgor/.local/lib/python3.12/site-packages (from pandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/namanbgor/.local/lib/python3.12/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/namanbgor/.local/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/namanbgor/.local/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/namanbgor/.local/lib/python3.12/site-packages (from xgboost) (2.20.5)
# Requirement already satisfied: six>=1.5 in /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error, mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_csv('Database.csv')
# df = df.sample(1000)
df['TIMEOFDAY'] = pd.to_datetime(df['DATETIME']).dt.time.apply(lambda x: int(x.strftime("%H%M%S")))
df.drop(["RID", "DATETIME"], axis=1, inplace=True)
featureNames = ['GHI', 'DNI', 'DHI', 'TEMP', 'WINDSPEED', 'HUMIDITY']
targetName = 'SOLAR_PROD'
x = df[featureNames].copy()
y = df[targetName]
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X=xTrain, y=yTrain)
# Out:
# LinearRegression()

# %%
yPred = model.predict(xTest)

# %%
rmse = root_mean_squared_error(yTest, yPred)
mse = mean_squared_error(yTest, yPred)
mae = mean_absolute_error(yTest, yPred)
r2 = r2_score(yTest, yPred)

# %%
print(f"\nRoot Mean Squared Error: {rmse}")
print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R-squared: {r2}")
# Out:
# Root Mean Squared Error: 1451.566791596908
# Mean Squared Error: 2107046.150466941
# Mean Absolute Error: 960.4584985159204
# R-squared: 0.8894408648495905

# %%
for featureName in featureNames:
    plt.figure(figsize=(8,6))
    plt.scatter(xTest[featureName], yTest, color='blue', label='Actual')
    plt.plot(xTest[featureName], yPred, color='red', linewidth=2, label='Predicted')
    plt.title(f'Regression Line (Feature: {featureName})')
    plt.xlabel(featureName)
    plt.ylabel(f'Target ({targetName})')
    plt.legend()
    plt.grid(True)
    plt.show()
